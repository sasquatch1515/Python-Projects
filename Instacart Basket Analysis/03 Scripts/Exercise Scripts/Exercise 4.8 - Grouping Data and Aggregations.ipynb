# %%
# import libraries
import pandas as pd
import numpy as np
import os

# %%
# import dataframe
df_ord_prod_merge = pd.read_pickle('/Users/samabrams/Data Analysis Projects/Instacart Basket Analysis/02 Data/Prepared Data/orders_products_merged_w_labels.pkl')

# %%
# Subset of first one million entries
df = df_ord_prod_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 20)

# %%
df.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   3139998      138            28                  6                 11
# 1   1977647      138            30                  6                 17
# 2    389851      709             2                  0                 21
# 3    652770      764             1                  3                 13
# 4   1813452      764             3                  4                 17
#
#    days_since_last_order  add_to_cart_order  reordered _merge source  \
# ...

# %% [markdown]
# ## Aggregating Data

# %%
# grouping data using pandas
df.groupby('product_name')

# %%
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.577493
# 2                17.320781
# 3                16.084944
# 4                17.530458
# 5                14.763075
# 6                16.658449
# 7                17.031590
# 8                15.076662
# 9                15.447580
# 10               18.681852
# 11               15.447411
# 12               14.327957
# 13               16.548642
# 14               16.960241
# 15               16.121948
# 16               17.803851
# 17               15.593633
# 18               19.674252
# 19               16.899756
# 20               16.255442
# 21               25.535479

# %% [markdown]
# The groupby() function is being assigned to the df dataframe, which creates the pandas object 'department_id'. The agg() function is then applied to this object and given a column name (order_number) and an aggregate function to apply to this column ('mean').

# %% [markdown]
# ## Performing Multiple Aggregations

# %%
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                15.577493   1  99
# 2                17.320781   1  96
# 3                16.084944   1  99
# 4                17.530458   1  99
# 5                14.763075   1  99
# 6                16.658449   1  99
# 7                17.031590   1  99
# 8                15.076662   1  98
# 9                15.447580   1  99
# 10               18.681852   1  99
# 11               15.447411   1  99
# 12               14.327957   1  99
# 13               16.548642   1  99
# 14               16.960241   1  99
# 15               16.121948   1  99
# 16               17.803851   1  99
# 17               15.593633   1  99
# 18               19.674252   1  99
# 19               16.899756   1  99
# 20               16.255442   1  99
# 21               25.535479   1  98

# %% [markdown]
# Code isn't too different, only more aggregate functions have been added

# %% [markdown]
# ## Aggregating Data with transform()

# %%
df_ord_prod_merge['max_order'] = df_ord_prod_merge.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# /var/folders/38/rbb9c58x57z0q20kbt7l13pr0000gn/T/ipykernel_32905/2783714032.py:1: FutureWarning: The provided callable <function max at 0x107acfc40> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   df_ord_prod_merge['max_order'] = df_ord_prod_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
df_ord_prod_merge['max_order'] = df_ord_prod_merge.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# /var/folders/38/rbb9c58x57z0q20kbt7l13pr0000gn/T/ipykernel_32905/2783714032.py:1: FutureWarning: The provided callable <function max at 0x107acfc40> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   df_ord_prod_merge['max_order'] = df_ord_prod_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
df_ord_prod_merge['max_order'] = df_ord_prod_merge.groupby(['user_id'])['order_number'].transform('max')

# %%
df_ord_prod_merge.head(30)
# Out:
#     product_id                product_name  aisle_id  department_id  prices  \
# 0            1  Chocolate Sandwich Cookies        61             19     5.8
# 1            1  Chocolate Sandwich Cookies        61             19     5.8
# 2            1  Chocolate Sandwich Cookies        61             19     5.8
# 3            1  Chocolate Sandwich Cookies        61             19     5.8
# 4            1  Chocolate Sandwich Cookies        61             19     5.8
# 5            1  Chocolate Sandwich Cookies        61             19     5.8
# 6            1  Chocolate Sandwich Cookies        61             19     5.8
# 7            1  Chocolate Sandwich Cookies        61             19     5.8
# 8            1  Chocolate Sandwich Cookies        61             19     5.8
# 9            1  Chocolate Sandwich Cookies        61             19     5.8
# 10           1  Chocolate Sandwich Cookies        61             19     5.8
# ...

# %%
# Remove limitation on maximum rows shown in head() and other functions
pd.options.display.max_rows = None

# %%
df_ord_prod_merge.head(100)
# Out:
#     product_id                product_name  aisle_id  department_id  prices  \
# 0            1  Chocolate Sandwich Cookies        61             19     5.8
# 1            1  Chocolate Sandwich Cookies        61             19     5.8
# 2            1  Chocolate Sandwich Cookies        61             19     5.8
# 3            1  Chocolate Sandwich Cookies        61             19     5.8
# 4            1  Chocolate Sandwich Cookies        61             19     5.8
# 5            1  Chocolate Sandwich Cookies        61             19     5.8
# 6            1  Chocolate Sandwich Cookies        61             19     5.8
# 7            1  Chocolate Sandwich Cookies        61             19     5.8
# 8            1  Chocolate Sandwich Cookies        61             19     5.8
# 9            1  Chocolate Sandwich Cookies        61             19     5.8
# 10           1  Chocolate Sandwich Cookies        61             19     5.8
# ...

# %% [markdown]
# ## Deriving Columns with loc()
# ### Creating Flags

# %%
df_ord_prod_merge.loc[df_ord_prod_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
df_ord_prod_merge.loc[(df_ord_prod_merge['max_order'] <= 40) & (df_ord_prod_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'
df_ord_prod_merge.loc[df_ord_prod_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
df_ord_prod_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
# Returning only certain columns from the head() function
df_ord_prod_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0       138  Regular customer            28
# 1       138  Regular customer            30
# 2       709      New customer             2
# 3       764      New customer             1
# 4       764      New customer             3
# 5       777  Regular customer            16
# 6       825      New customer             3
# 7       910  Regular customer            12
# 8      1052  Regular customer            10
# 9      1052  Regular customer            15
# 10     1379      New customer             1
# 11     1480    Loyal customer            36
# 12     1480    Loyal customer            38
# 13     1480    Loyal customer            39
# 14     1494  Regular customer             6
# 15     1494  Regular customer             7
# 16     1494  Regular customer             9
# 17     1540  Regular customer             4
# 18     1540  Regular customer             5
# 19     1540  Regular customer             6
# ...

# %%
df_ord_prod_merge.to_pickle('/Users/samabrams/Data Analysis Projects/Instacart Basket Analysis/02 Data/Prepared Data/orders_products_merged_flagged.pkl')
