# %%
# Importing Libraries
import pandas as pd
import numpy as np
import os

# %%
# Import Datasets
df_ord_prior = pd.read_csv('/Users/samabrams/Data Analysis Projects/Instacart Basket Analysis/02 Data/Original Data/orders_products_prior.csv')

# %%
df_ord_prior
# Out:
#           order_id  product_id  add_to_cart_order  reordered
# 0                2       33120                  1          1
# 1                2       28985                  2          1
# 2                2        9327                  3          0
# 3                2       45918                  4          1
# 4                2       30035                  5          0
# ...            ...         ...                ...        ...
# 32434484   3421083       39678                  6          1
# 32434485   3421083       11352                  7          0
# 32434486   3421083        4600                  8          0
# 32434487   3421083       24852                  9          1
# 32434488   3421083        5020                 10          1
#
# [32434489 rows x 4 columns]

# %%
df_ord = pd.read_csv('/Users/samabrams/Data Analysis Projects/Instacart Basket Analysis/02 Data/Prepared Data/orders_checked')

# %%
df_ord.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2398795        1             2                  3                  7
# 2    473747        1             3                  3                 12
# 3   2254736        1             4                  4                  7
# 4    431534        1             5                  4                 15
#
#    days_since_last_order
# 0                    NaN
# 1                   15.0
# 2                   21.0
# 3                   29.0
# 4                   28.0

# %%
df_ord.shape
# Out:
# (3421083, 6)

# %%
dford_prior.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 dford_prior.shape
#
# NameError: name 'dford_prior' is not defined

# %%
df_ord_prior.shape
# Out:
# (32434489, 4)

# %%
df_ord_merged = df_ord.merge(df_ord_prior, on = 'order_id', indicator=True)

# %%
df_ord_merged
# Out:
#           order_id  user_id  order_number  order_day_of_week  \
# 0          2539329        1             1                  2
# 1          2539329        1             1                  2
# 2          2539329        1             1                  2
# 3          2539329        1             1                  2
# 4          2539329        1             1                  2
# ...            ...      ...           ...                ...
# 32434484   2977660   206209            13                  1
# 32434485   2977660   206209            13                  1
# 32434486   2977660   206209            13                  1
# 32434487   2977660   206209            13                  1
# 32434488   2977660   206209            13                  1
#
#           order_hour_of_day  days_since_last_order  product_id  \
# 0                         8                    NaN         196
# 1                         8                    NaN       14084
# ...

# %%
df_ored_merged.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 df_ored_merged.shape
#
# NameError: name 'df_ored_merged' is not defined

# %%
df_ord_merged.shape
# Out:
# (32434489, 10)

# %%
# exporting order_product_prior as a pickle
df_ord_merged.to_pickle(os.path.join('/Users/samabrams/Data Analysis Projects/Instacart Basket Analysis/02 Data/Prepared Data', 'orders_products_combined.pkl'))
