# %%
# File name: Exercise 4.10 - Creating Customer Profiles
# Author: Sam Abrams
# Created: 12/27/24
# Description: This notebook drops personal identifying information along with other non-essential columns, then focuses on creating profiles that group customers into defined profiles based on age, income, and number of dependents.

# %% [markdown]
# ## Initial Notebook Setup

# %%
# import libraries
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_all_top = pd.read_pickle("C:/Users/Sam/Documents/Data Analytics Projects/02 Data/ALL_order_prod_cust_dataframe.pkl")

# %%
df_all_top.shape
# Out:
# (32404859, 35)

# %%
df_all = df_all_top

# %%
df_all.shape
# Out:
# (32404859, 35)

# %% [markdown]
# I wanted to change the name of the dataframe to avoid confusion, hence the df_all name above.

# %% [markdown]
# ## Handling PII Concerns and Dropping Unnecessary Columns

# %% [markdown]
# The code below will create a new dataframe that doesn't contain the first and last names of the customers. User_ID will be the primary identifier for each customer, and the pertinent demographic info has been retained.

# %%
df_all_scrub = df_all.drop(['first_name', 'last_name', 'date_joined', 'add_to_cart_order', '_merge', 'source', 'aisle_id', 'product_name', 'order_id', 'max_order', 'price_range_loc', 'median_order_freq', 'average_price'], axis=1)

# %%
df_all_scrub.head(50)
# Out:
#     product_id  department_id  prices  user_id  order_number  \
# 0            1             19     5.8      138            28
# 1            1             19     5.8      138            30
# 2            1             19     5.8      709             2
# 3            1             19     5.8      764             1
# 4            1             19     5.8      764             3
# 5            1             19     5.8      777            16
# 6            1             19     5.8      825             3
# 7            1             19     5.8      910            12
# 8            1             19     5.8     1052            10
# 9            1             19     5.8     1052            15
# 10           1             19     5.8     1379             1
# 11           1             19     5.8     1480            36
# 12           1             19     5.8     1480            38
# 13           1             19     5.8     1480            39
# 14           1             19     5.8     1494             6
# 15           1             19     5.8     1494             7
# 16           1             19     5.8     1494             9
# 17           1             19     5.8     1540             4
# 18           1             19     5.8     1540             5
# 19           1             19     5.8     1540             6
# 20           1             19     5.8     1540             7
# 21           1             19     5.8     1540             8
# 22           1             19     5.8     1540             9
# 23           1             19     5.8     1540            14
# 24           1             19     5.8     1540            15
# 25           1             19     5.8     1540            18
# 26           1             19     5.8     1540            19
# 27           1             19     5.8     1540            20
# 28           1             19     5.8     1540            21
# 29           1             19     5.8     1540            22
# 30           1             19     5.8     1540            24
# 31           1             19     5.8     1540            25
# 32           1             19     5.8     1540            27
# 33           1             19     5.8     1540            28
# 34           1             19     5.8     1598             1
# 35           1             19     5.8     1598             2
# 36           1             19     5.8     1598             3
# 37           1             19     5.8     1647             1
# 38           1             19     5.8     1647             4
# 39           1             19     5.8     1647             6
# 40           1             19     5.8     1647             8
# 41           1             19     5.8     1647             9
# 42           1             19     5.8     2833             1
# 43           1             19     5.8     2850             7
# 44           1             19     5.8     2857            24
# 45           1             19     5.8     3010             5
# 46           1             19     5.8     3029             1
# 47           1             19     5.8     3395             4
# 48           1             19     5.8     3904             1
# 49           1             19     5.8     4006             2
#
#     order_day_of_week  order_hour_of_day  days_since_last_order  reordered  \
# 0                   6                 11                    3.0          0
# 1                   6                 17                   20.0          1
# 2                   0                 21                    6.0          0
# 3                   3                 13                    NaN          0
# 4                   4                 17                    9.0          1
# 5                   1                  7                   26.0          0
# 6                   2                 14                   30.0          0
# 7                   3                 10                   30.0          0
# 8                   1                 20                   19.0          0
# 9                   1                 12                   15.0          1
# 10                  5                 11                    NaN          0
# 11                  3                 13                    7.0          0
# 12                  4                 13                    7.0          1
# 13                  2                 12                   12.0          1
# 14                  3                 10                    2.0          0
# 15                  2                  8                    6.0          1
# 16                  5                  8                   10.0          1
# 17                  2                  0                    7.0          0
# 18                  1                 21                    6.0          1
# 19                  1                  0                   14.0          1
# 20                  2                  2                    8.0          1
# 21                  1                 23                    6.0          1
# 22                  1                  3                   28.0          1
# 23                  1                 14                    7.0          1
# 24                  1                 14                    7.0          1
# 25                  0                 21                    0.0          1
# 26                  0                 22                    7.0          1
# 27                  0                 22                    7.0          1
# 28                  0                 20                    7.0          1
# 29                  0                 22                    7.0          1
# 30                  4                 22                    3.0          1
# 31                  6                 19                   16.0          1
# 32                  1                  1                    5.0          1
# 33                  0                 21                    6.0          1
# 34                  2                 12                    NaN          0
# 35                  2                 10                   21.0          1
# 36                  4                 17                    2.0          1
# 37                  1                  9                    NaN          0
# 38                  0                 13                   18.0          1
# 39                  1                  9                    8.0          1
# 40                  0                 17                   30.0          1
# 41                  4                 15                   25.0          1
# 42                  0                 14                    NaN          0
# 43                  1                 16                    9.0          0
# 44                  1                  8                   10.0          0
# 45                  3                 10                    7.0          0
# 46                  2                 20                    NaN          0
# 47                  2                 10                   30.0          0
# 48                  1                 14                    NaN          0
# 49                  1                 10                    7.0          0
#
#           price_range  ... busiest_period_of_day      loyalty_flag  \
# 0   mid-range product  ...           Most Orders  Regular customer
# 1   mid-range product  ...        Average Orders  Regular customer
# 2   mid-range product  ...        Average Orders      New customer
# 3   mid-range product  ...           Most Orders      New customer
# 4   mid-range product  ...        Average Orders      New customer
# 5   mid-range product  ...        Average Orders  Regular customer
# 6   mid-range product  ...           Most Orders      New customer
# 7   mid-range product  ...           Most Orders  Regular customer
# 8   mid-range product  ...        Average Orders  Regular customer
# 9   mid-range product  ...           Most Orders  Regular customer
# 10  mid-range product  ...           Most Orders      New customer
# 11  mid-range product  ...           Most Orders    Loyal customer
# 12  mid-range product  ...           Most Orders    Loyal customer
# 13  mid-range product  ...           Most Orders    Loyal customer
# 14  mid-range product  ...           Most Orders  Regular customer
# 15  mid-range product  ...        Average Orders  Regular customer
# 16  mid-range product  ...        Average Orders  Regular customer
# 17  mid-range product  ...         Fewest Orders  Regular customer
# 18  mid-range product  ...        Average Orders  Regular customer
# 19  mid-range product  ...         Fewest Orders  Regular customer
# 20  mid-range product  ...         Fewest Orders  Regular customer
# 21  mid-range product  ...         Fewest Orders  Regular customer
# 22  mid-range product  ...         Fewest Orders  Regular customer
# 23  mid-range product  ...           Most Orders  Regular customer
# 24  mid-range product  ...           Most Orders  Regular customer
# 25  mid-range product  ...        Average Orders  Regular customer
# 26  mid-range product  ...        Average Orders  Regular customer
# 27  mid-range product  ...        Average Orders  Regular customer
# 28  mid-range product  ...        Average Orders  Regular customer
# 29  mid-range product  ...        Average Orders  Regular customer
# 30  mid-range product  ...        Average Orders  Regular customer
# 31  mid-range product  ...        Average Orders  Regular customer
# 32  mid-range product  ...         Fewest Orders  Regular customer
# 33  mid-range product  ...        Average Orders  Regular customer
# 34  mid-range product  ...           Most Orders      New customer
# 35  mid-range product  ...           Most Orders      New customer
# 36  mid-range product  ...        Average Orders      New customer
# 37  mid-range product  ...           Most Orders      New customer
# 38  mid-range product  ...           Most Orders      New customer
# 39  mid-range product  ...           Most Orders      New customer
# 40  mid-range product  ...        Average Orders      New customer
# 41  mid-range product  ...           Most Orders      New customer
# 42  mid-range product  ...           Most Orders      New customer
# 43  mid-range product  ...           Most Orders  Regular customer
# 44  mid-range product  ...        Average Orders  Regular customer
# 45  mid-range product  ...           Most Orders  Regular customer
# 46  mid-range product  ...        Average Orders      New customer
# 47  mid-range product  ...           Most Orders      New customer
# 48  mid-range product  ...           Most Orders      New customer
# 49  mid-range product  ...           Most Orders    Loyal customer
#
#    spending_flag              freq_flag  Gender                 state Age  \
# 0    low spender      frequent customer    Male             Minnesota  81
# 1    low spender      frequent customer    Male             Minnesota  81
# 2    low spender      frequent customer  Female               Vermont  66
# 3    low spender      frequent customer  Female             Wisconsin  40
# 4    low spender      frequent customer  Female             Wisconsin  40
# 5    low spender       Regular customer  Female                Hawaii  51
# 6    low spender       Regular customer    Male  District of Columbia  20
# 7    low spender      frequent customer  Female             Tennessee  65
# 8    low spender      frequent customer    Male                Oregon  72
# 9    low spender      frequent customer    Male                Oregon  72
# 10   low spender       Regular customer    Male                Alaska  61
# 11   low spender      frequent customer    Male               Alabama  19
# 12   low spender      frequent customer    Male               Alabama  19
# 13   low spender      frequent customer    Male               Alabama  19
# 14   low spender      frequent customer  Female               Indiana  78
# 15   low spender      frequent customer  Female               Indiana  78
# 16   low spender      frequent customer  Female               Indiana  78
# 17   low spender      frequent customer    Male               Florida  76
# 18   low spender      frequent customer    Male               Florida  76
# 19   low spender      frequent customer    Male               Florida  76
# 20   low spender      frequent customer    Male               Florida  76
# 21   low spender      frequent customer    Male               Florida  76
# 22   low spender      frequent customer    Male               Florida  76
# 23   low spender      frequent customer    Male               Florida  76
# 24   low spender      frequent customer    Male               Florida  76
# 25   low spender      frequent customer    Male               Florida  76
# 26   low spender      frequent customer    Male               Florida  76
# 27   low spender      frequent customer    Male               Florida  76
# 28   low spender      frequent customer    Male               Florida  76
# 29   low spender      frequent customer    Male               Florida  76
# 30   low spender      frequent customer    Male               Florida  76
# 31   low spender      frequent customer    Male               Florida  76
# 32   low spender      frequent customer    Male               Florida  76
# 33   low spender      frequent customer    Male               Florida  76
# 34   low spender      frequent customer    Male                Kansas  41
# 35   low spender      frequent customer    Male                Kansas  41
# 36   low spender      frequent customer    Male                Kansas  41
# 37   low spender  non-frequent customer    Male               Indiana  67
# 38   low spender  non-frequent customer    Male               Indiana  67
# 39   low spender  non-frequent customer    Male               Indiana  67
# 40   low spender  non-frequent customer    Male               Indiana  67
# 41   low spender  non-frequent customer    Male               Indiana  67
# 42   low spender       Regular customer    Male        North Carolina  37
# 43   low spender      frequent customer    Male                  Utah  22
# 44   low spender       Regular customer  Female               Alabama  30
# 45   low spender      frequent customer  Female               Alabama  65
# 46   low spender  non-frequent customer    Male                 Maine  37
# 47   low spender       Regular customer  Female          North Dakota  54
# 48   low spender  non-frequent customer    Male        North Carolina  73
# 49   low spender      frequent customer    Male        North Carolina  28
#
#    num_dependents                        fam_status  income
# 0               1                           married   49620
# 1               1                           married   49620
# 2               2                           married  158302
# 3               3                           married   31308
# 4               3                           married   31308
# 5               2                           married   57797
# 6               3  living with parents and siblings   34171
# 7               0                  divorced/widowed   44856
# 8               1                           married  153843
# 9               1                           married  153843
# 10              1                           married   42573
# 11              1  living with parents and siblings   32283
# 12              1  living with parents and siblings   32283
# 13              1  living with parents and siblings   32283
# 14              1                           married   49504
# 15              1                           married   49504
# 16              1                           married   49504
# 17              3                           married   53340
# 18              3                           married   53340
# 19              3                           married   53340
# 20              3                           married   53340
# 21              3                           married   53340
# 22              3                           married   53340
# 23              3                           married   53340
# 24              3                           married   53340
# 25              3                           married   53340
# 26              3                           married   53340
# 27              3                           married   53340
# 28              3                           married   53340
# 29              3                           married   53340
# 30              3                           married   53340
# 31              3                           married   53340
# 32              3                           married   53340
# 33              3                           married   53340
# 34              2                           married  122060
# 35              2                           married  122060
# 36              2                           married  122060
# 37              0                  divorced/widowed   39869
# 38              0                  divorced/widowed   39869
# 39              0                  divorced/widowed   39869
# 40              0                  divorced/widowed   39869
# 41              0                  divorced/widowed   39869
# 42              2                           married   56559
# 43              1                           married   46105
# 44              2                           married   91407
# 45              2                           married   32017
# 46              1                           married   82441
# 47              2                           married   53401
# 48              2                           married  106683
# 49              0                            single   96906
#
# [50 rows x 22 columns]

# %% [markdown]
# ## Assigning Regions to Customers

# %%
df_all_scrub['state'].value_counts(dropna=False)
# Out:
# state
# Pennsylvania            667082
# California              659783
# Rhode Island            656913
# Georgia                 656389
# New Mexico              654494
# Arizona                 653964
# North Carolina          651900
# Oklahoma                651739
# Alaska                  648495
# Minnesota               647825
# Massachusetts           646358
# Wyoming                 644255
# Virginia                641421
# Missouri                640732
# Texas                   640394
# Colorado                639280
# Maine                   638583
# North Dakota            638491
# Alabama                 638003
# Kansas                  637538
# Louisiana               637482
# Delaware                637024
# South Carolina          636754
# Oregon                  636425
# Arkansas                636144
# Nevada                  636139
# New York                635983
# Montana                 635265
# South Dakota            633772
# Illinois                633024
# Hawaii                  632901
# Washington              632852
# Mississippi             632675
# Kentucky                632490
# Michigan                630928
# Florida                 629027
# Ohio                    628319
# Wisconsin               628108
# New Jersey              627692
# Indiana                 627282
# Maryland                626579
# Nebraska                625813
# Iowa                    625493
# Connecticut             623022
# Tennessee               617873
# New Hampshire           615378
# District of Columbia    613695
# West Virginia           612296
# Utah                    611941
# Vermont                 611725
# Idaho                   607119
# Name: count, dtype: int64

# %%
def assign_region(state):
    if state in ['Maine', 'New Hampshire', 'Vermont', 'Massachusetts', 'Rhode Island', 'Connecticut', 'New York', 'Pennsylvania', 'New Jersey']:
        return 'Northeast'
    elif state in ['Wisconsin', 'Michigan', 'Illinois', 'Indiana', 'Ohio', 'North Dakota', 'South Dakota', 'Nebraska', 'Kansas', 'Minnesota', 'Iowa', 'Missouri']:
        return 'Midwest'
    elif state in ['Delaware', 'Maryland', 'District of Columbia', 'Virginia', 'West Virginia', 'North Carolina', 'South Carolina', 'Georgia', 'Florida', 'Kentucky', 'Tennessee', 'Mississippi', 'Alabama', 'Oklahoma', 'Texas', 'Arkansas', 'Louisiana']:
        return 'South'
    elif state in ['Idaho', 'Montana', 'Wyoming', 'Nevada', 'Utah', 'Colorado', 'Arizona', 'New Mexico', 'Alaska', 'Washington', 'Oregon', 'California', 'Hawaii']:
        return 'West'

# %%
df_all_scrub['Region'] = df_all_scrub['state'].apply(assign_region)

# %%
df_all_scrub.head()
# Out:
#    product_id  department_id  prices  user_id  order_number  \
# 0           1             19     5.8      138            28
# 1           1             19     5.8      138            30
# 2           1             19     5.8      709             2
# 3           1             19     5.8      764             1
# 4           1             19     5.8      764             3
#
#    order_day_of_week  order_hour_of_day  days_since_last_order  reordered  \
# 0                  6                 11                    3.0          0
# 1                  6                 17                   20.0          1
# 2                  0                 21                    6.0          0
# 3                  3                 13                    NaN          0
# 4                  4                 17                    9.0          1
#
#          price_range  ...      loyalty_flag spending_flag          freq_flag  \
# 0  mid-range product  ...  Regular customer   low spender  frequent customer
# 1  mid-range product  ...  Regular customer   low spender  frequent customer
# 2  mid-range product  ...      New customer   low spender  frequent customer
# 3  mid-range product  ...      New customer   low spender  frequent customer
# 4  mid-range product  ...      New customer   low spender  frequent customer
#
#    Gender      state Age num_dependents fam_status  income     Region
# 0    Male  Minnesota  81              1    married   49620    Midwest
# 1    Male  Minnesota  81              1    married   49620    Midwest
# 2  Female    Vermont  66              2    married  158302  Northeast
# 3  Female  Wisconsin  40              3    married   31308    Midwest
# 4  Female  Wisconsin  40              3    married   31308    Midwest
#
# [5 rows x 23 columns]

# %%
df_all_scrub = df_all_scrub.drop('state', axis=1)

# %%
df_all_scrub.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32404859 entries, 0 to 32404858
# Data columns (total 22 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   product_id             int64
#  1   department_id          int64
#  2   prices                 float64
#  3   user_id                int64
#  4   order_number           int64
#  5   order_day_of_week      int64
#  6   order_hour_of_day      int64
#  7   days_since_last_order  float64
#  8   reordered              int64
#  9   price_range            object
#  10  busiest days           object
#  11  busiest day            object
#  12  busiest_period_of_day  object
#  13  loyalty_flag           object
#  14  spending_flag          object
#  15  freq_flag              object
#  16  Gender                 object
#  17  Age                    int64
#  18  num_dependents         int64
#  19  fam_status             object
#  20  income                 int64
#  21  Region                 object
# dtypes: float64(2), int64(10), object(10)
# memory usage: 5.3+ GB

# %% [markdown]
# ## Creating exclusion flag for, and subsequently removing, low-activity customers

# %%
## calculate the number of orders for each customer
orders_per_customer = df_all_scrub.groupby('user_id')['order_number'].count()

# %%
## Filter to keep only customers with 5 or more orders
frequent_customers = orders_per_customer[orders_per_customer >= 6].index

# %%
## New dataframe with only customers who have 6 or more orders, thereby excluding customers with 5 or less
df_all_top = df_all_scrub[df_all_scrub['user_id'].isin(frequent_customers)]
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[26], line 2
#       1 ## New dataframe with only customers who have 6 or more orders, thereby excluding customers with 5 or less
# ----> 2 df_all_top = df_all_scrub[df_all_scrub['user_id'].isin(frequent_customers)]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4093, in DataFrame.__getitem__(self, key)
#    4091 # Do we have a (boolean) 1d indexer?
#    4092 if com.is_bool_indexer(key):
# -> 4093     return self._getitem_bool_array(key)
#    4095 # We are left with two options: a single key, and a collection of keys,
#    4096 # We interpret tuples as collections only for non-MultiIndex
#    4097 is_single_key = isinstance(key, tuple) or not is_list_like(key)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4155, in DataFrame._getitem_bool_array(self, key)
#    4152     return self.copy(deep=None)
#    4154 indexer = key.nonzero()[0]
# -> 4155 return self._take_with_is_copy(indexer, axis=0)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4153, in NDFrame._take_with_is_copy(self, indices, axis)
#    4142 @final
#    4143 def _take_with_is_copy(self, indices, axis: Axis = 0) -> Self:
#    4144     """
#    4145     Internal version of the `take` method that sets the `_is_copy`
#    4146     attribute to keep track of the parent dataframe (using in indexing
#    (...)
#    4151     See the docstring of `take` for full explanation of the parameters.
#    4152     """
# -> 4153     result = self.take(indices=indices, axis=axis)
#    4154     # Maybe set copy if we didn't actually change the index.
#    4155     if self.ndim == 2 and not result._get_axis(axis).equals(self._get_axis(axis)):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4133, in NDFrame.take(self, indices, axis, **kwargs)
#    4128     # We can get here with a slice via DataFrame.__getitem__
#    4129     indices = np.arange(
#    4130         indices.start, indices.stop, indices.step, dtype=np.intp
#    4131     )
# -> 4133 new_data = self._mgr.take(
#    4134     indices,
#    4135     axis=self._get_block_manager_axis(axis),
#    4136     verify=True,
#    4137 )
#    4138 return self._constructor_from_mgr(new_data, axes=new_data.axes).__finalize__(
#    4139     self, method="take"
#    4140 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:894, in BaseBlockManager.take(self, indexer, axis, verify)
#     891 indexer = maybe_convert_indices(indexer, n, verify=verify)
#     893 new_labels = self.axes[axis].take(indexer)
# --> 894 return self.reindex_indexer(
#     895     new_axis=new_labels,
#     896     indexer=indexer,
#     897     axis=axis,
#     898     allow_dups=True,
#     899     copy=None,
#     900 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:688, in BaseBlockManager.reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, only_slice, use_na_proxy)
#     680     new_blocks = self._slice_take_blocks_ax0(
#     681         indexer,
#     682         fill_value=fill_value,
#     683         only_slice=only_slice,
#     684         use_na_proxy=use_na_proxy,
#     685     )
#     686 else:
#     687     new_blocks = [
# --> 688         blk.take_nd(
#     689             indexer,
#     690             axis=1,
#     691             fill_value=(
#     692                 fill_value if fill_value is not None else blk.fill_value
#     693             ),
#     694         )
#     695         for blk in self.blocks
#     696     ]
#     698 new_axes = list(self.axes)
#     699 new_axes[axis] = new_axis
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:1307, in Block.take_nd(self, indexer, axis, new_mgr_locs, fill_value)
#    1304     allow_fill = True
#    1306 # Note: algos.take_nd has upcast logic similar to coerce_to_target_dtype
# -> 1307 new_values = algos.take_nd(
#    1308     values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#    1309 )
#    1311 # Called from three places in managers, all of which satisfy
#    1312 #  these assertions
#    1313 if isinstance(self, ExtensionBlock):
#    1314     # NB: in this case, the 'axis' kwarg will be ignored in the
#    1315     #  algos.take_nd call above.
#
# File ~\anaconda3\Lib\site-packages\pandas\core\array_algos\take.py:117, in take_nd(arr, indexer, axis, fill_value, allow_fill)
#     114     return arr.take(indexer, fill_value=fill_value, allow_fill=allow_fill)
#     116 arr = np.asarray(arr)
# --> 117 return _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\array_algos\take.py:157, in _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#     155     out = np.empty(out_shape, dtype=dtype, order="F")
#     156 else:
# --> 157     out = np.empty(out_shape, dtype=dtype)
#     159 func = _get_take_nd_function(
#     160     arr.ndim, arr.dtype, out.dtype, axis=axis, mask_info=mask_info
#     161 )
#     162 func(arr, indexer, out, fill_value)
#
# MemoryError: Unable to allocate 1.69 GiB for an array with shape (7, 32398590) and data type object

# %%
df_all_scrub.shape

# %%
df_all_top.shape

# %% [markdown]
# 6,269 records were removed as a result of the low-activity flag.

# %% [markdown]
# ## Changing Column Data Types

# %% [markdown]
# The dataframe was challenging the extent of my RAM, so I'm changing a few data types from object to category in hopes of decreasing the load.

# %%
columns_to_convert = ['Region', 'fam_status', 'Gender', 'freq_flag', 'spending_flag', 'loyalty_flag', 'busiest day', 'price_range']

for column in columns_to_convert:
    df_all_top[column] = df_all_top[column].astype('category')

# %%
df_all_top.info()

# %%
df_all_top = df_all_top.rename(columns={'Age':'age',})

# %% [markdown]
# ## Creating Customer Profiles

# %%
## Creates two different profiles, one based on age and income, the other based on age and dependents

def get_age_group(age):

    if age <= 30:
        return 'Young Adult'
    elif age <= 60:
        return 'Middle-Aged Adult'
    else:
        return 'Older Adult'

def get_income_group(income):
    if income <= 67000:
        return 'Low-Income'
    elif income <= 170000:
        return 'Middle-Income'
    else:
        return 'High-Income'

def get_dependent_status(row):
    if row['num_dependents'] > 0:
        if row['fam_status'] in ('single', 'divorced/widowed'):
            return 'Single Parent'
        else:
            return 'Parent'
    else:
        return 'No Dependents'

# %%
df_all_top['age_group'] = df_all_top['age'].apply(get_age_group)

# %%
df_all_top['income_group'] = df_all_top['income'].apply(get_income_group)

# %%
df_all_top['dependent_status'] = df_all_top.apply(get_dependent_status, axis=1)

# %%
df_all_top.head(20)

# %%
# Combine the columns to create the final profile columns
df_all_top['income_profile'] = df_all_top['income_group'] + ' ' + df_all_top['age_group']
df_all_top['dependent_profile'] = df_all_top['age_group'] + ', ' + df_all_top['dependent_status']

# %%
pd.set_option('display.max_columns', None)

# %%
df_all_top.head()

# %%
df_all_top.info()

# %%
columns_to_convert2 = ['age_group', 'income_group', 'dependent_status', 'income_profile', 'dependent_profile']

for column in columns_to_convert2:
    df_all_top[column] = df_all_top[column].astype('category')

# %%
df_all_top.to_pickle('C:/Users/Sam/Documents/Data Analytics Projects/02 Data/OPC_scrubbed_profiled.pkl')

# %% [markdown]
# I wanted to save the data here because it took so long to create this new database with the customer profiles, and I didn't want to risk losing that file.

# %% [markdown]
# ## Visualizations for Distribution of Profiles

# %%
df_OPC = pd.read_pickle('C:/Users/Sam/Documents/Data Analytics Projects/02 Data/OPC_scrubbed_profiled.pkl')
